# %% [markdown]
# # Fake News Detection: an application of classic NLP techniques
# **Universidade de Brasília**<br>
# School of Technology<br>
# Graduate Program in Electrical Engineering (PPGEE)
#
# ## Author: Stefano M P C Souza (stefanomozart@ieee.org)<br> Advisor: Daniel G Silva<br>Advisor: Anderson C A Nascimento

# %% [markdown]
# ## 1. Experiment design
#
# We want to study the impact of various NLP preprocessing techniques in the task of text classification for fake news detection. We are going to use the pipeline from [1] for model traing, tuning (hyper-parameter search) and comparison. The following ML algorithms are used:
# 1. Naive Bayes:
# 2. Decision Trees:
# 2. K-Nearest Neighbour:
# 3. Logistic Regression:
# 3. Suport-Vector Machines:
# 4. Random Forest:
# 5. XGBoost:
#
# All models are trained and tested on a binary (*fake*/real) classification task. The *pipeline*, written by the author, extends the `sklearn.pipeline.Pipeline` class, from scikit-learn, and consists of the following steps:
# 1. **Training and tuning**: uses a random search algorithm to select the best hyper-parameters for each ML model;
# 2. **Selection**: for each dataset, selects the models with best performance, on the selected metric, for the validation set. The selected model is trained one more time with the concatanation of the training and the valiudation set;
# 5. **Test**: the models selected on the previous step, and trained on training+validation sets are used to classify texts in the test set. The final score, on the selected metric, is record so we can compare .

# %% [markdown]
# ### 1.1. Datasets
#
# We selected 2 datasets in English and 2 in Portuguese. Each pair has a dataset with full-length news
# articles and a dataset comprised of short statements, or sentences. The purpose of experimenting
# with different languages and text sizes was to observe how these variables may impact preprocessing
# and training cost, and, ultimately, model performance.
#
# The selected datasets are:
#   - **Liar Dataset (liar):** curated by the UC Santa Barbara NLP Group, contains 12791 claims
#   by North-American politicians and celebrities, classified as `true`, `mostly-true`, `half-true`,
#   `barely-true`, `false` and `pants-on-fire` [[2](#liar)];
#
#   - **Source Based Fake News Classification (sbnc):** 2020 full-length news manually labeled
#   as `Real` or `Fake` [[3](#sbnc)];
#
#   - **FactCk.br:** 1313 claims by Brazilian politicians, manually annotated by fact checking agencies\footnote{\url{https://piaui.folha.uol.com.br/lupa}, \url{https://www.aosfatos.org} and \url{https://apublica.org}} as `true`, `false`, `imprecise` and `others` [[4](#factckbr)];
#
#   - **Fake.br:** 7200 full-length news articles, with text and metadata, manually flagged as `real` or `fake` news [[5](#fakebr)].
#
# The classification experiments were preceded by a dataset preparation so that each dataset would have the same structure:
# 1. **label**: (boolean) indicating if that text was labeled as *fake news*;
# 2. **text**: (string) a concatenation of title (when available) and news body.

# %% [markdown]
# ### 1.2. Pre-processing
#
# See the [Classic NLP](./classic_nlp.ipynb) notebook for details.

# %% [markdown]
# ## 2. Classic ML Experiments
#
# The experiments differ, in fact, in the preprocessing step, by the application of the following NLP techniques:
#
# E1. Bag-of-Words (BoW);<br>
# E2. Stop-word Removal (SwR) and BoW;<br>
# E3. *Stemming* and BoW;<br>
# E4. Lemmatization and BoW;<br>
# E5. SwR, lemmatization and BoW;<br>
# E6. TF-IDF;<br>
# E7. SwR and TF-IDF;<br>
# E8. *Stemming* and TF-IDF;<br>
# E9. Lemmatization and TF-IDF;<br>
# E10. SwR, lemmatization and TF-IDF;<br>
# E11. DiltilBERT word embeddings;<br>
# E12. Sentence-BERT sentence embeddings.

# %% [markdown]
# **Loading the preprocessed datasets**<BR>

# %%
import pandas as pd
import numpy as np
import joblib

datasets = joblib.load('datasets.pyd')
experiments = joblib.load('experiments.pyd')

# %% [markdown]
# **Loading the model selection pipeline from [[1](#bot)]**

# %%
from scipy.sparse import load_npz
from bc_pipeline import ModelSelection

results = lambda: None
results.info = pd.DataFrame()
results.best_model = pd.DataFrame()

# %% [markdown]
# ### 4.1. Running the model selection pipeline

# %%
for e in experiments.values():
    for d in datasets:
        print('Runnning ', e['name'], d['name'])
        train = load_npz(f"datasets/{d['name']}/train.{e['name']}.npz")
        train_valid = load_npz(f"datasets/{d['name']}/train.valid.{e['name']}.npz")
        valid = load_npz(f"datasets/{d['name']}/valid.{e['name']}.npz")
        test = load_npz(f"datasets/{d['name']}/test.{e['name']}.npz")
                
        # Instanciate model selection class
        mdl = ModelSelection(
            n_iter=20,
            cv_scoring='f1',
            selection_scoring='roc_auc',
            save_models=True,
            output_path=f"{e['name']}/{d['name']}",
            name=f"{e['name']}_{d['name']}"
        )

        # tune the internal models
        mdl.tune(train, d['train'].label)

        # select the best model for the experiment
        mdl.select(valid, d['valid'].label)

        # Fit the selected model with train+validation sets
        mdl.fit(train_valid, d['train.valid'].label)

        # test the selected model
        mdl.score(test, d['test'].label)
        display(mdl._score)
        
        results.info = results.info.append(mdl._info)
        results.best_model = results.best_model.append(mdl._score)
# Out:
# Runnning  bow liar
#    pipeline scaling   model_name                         params  \
# 0  bow_liar    none  Naive Bayes  {'norm': False, 'alpha': 0.8}
#
#   training_scoring  training_score validation_scoring  validation_score  \
# 0               f1        0.551215            roc_auc          0.595368
#
#    accuracy       f1   roc_auc   runtime
# 0  0.613912  0.61337  0.607433  0.297642
# Runnning  bow sbnc
# /opt/conda/lib/python3.8/site-packages/xgboost/sklearn.py:1224: UserWarning: The use of label encoder in XGBClassifier is deprecated and will be removed in a future release. To remove this warning, do the following: 1) Pass option use_label_encoder=False when constructing XGBClassifier object; and 2) Encode your labels (y) as integers starting with 0, i.e. 0, 1, 2, ..., [num_class - 1].
#   warnings.warn(label_encoder_deprecation_msg, UserWarning)
# [14:40:50] WARNING: ../src/learner.cc:1115: Starting in XGBoost 1.3.0, the default evaluation metric used with the objective 'binary:logistic' was changed from 'error' to 'logloss'. Explicitly set eval_metric if you'd like to restore the old behavior.
#    pipeline scaling model_name  \
# 0  bow_sbnc    none    XGBoost
#
#                                               params training_scoring  \
# 0  {'learning_rate': 0.037999397928169254, 'max_d...               f1
#
#    training_score validation_scoring  validation_score  accuracy        f1  \
# 0        0.830805            roc_auc          0.796636  0.769802  0.763858
#
#    roc_auc    runtime
# 0  0.74165  53.888175
# Runnning  bow fake.br
# /opt/conda/lib/python3.8/site-packages/xgboost/sklearn.py:1224: UserWarning: The use of label encoder in XGBClassifier is deprecated and will be removed in a future release. To remove this warning, do the following: 1) Pass option use_label_encoder=False when constructing XGBClassifier object; and 2) Encode your labels (y) as integers starting with 0, i.e. 0, 1, 2, ..., [num_class - 1].
#   warnings.warn(label_encoder_deprecation_msg, UserWarning)
# [14:41:06] WARNING: ../src/learner.cc:1115: Starting in XGBoost 1.3.0, the default evaluation metric used with the objective 'binary:logistic' was changed from 'error' to 'logloss'. Explicitly set eval_metric if you'd like to restore the old behavior.
#       pipeline scaling model_name  \
# 0  bow_fake.br    none    XGBoost
#
#                                               params training_scoring  \
# 0  {'learning_rate': 0.13740346640696569, 'max_de...               f1
#
#    training_score validation_scoring  validation_score  accuracy        f1  \
# 0        0.965594            roc_auc          0.967882  0.975694  0.975693
#
#     roc_auc    runtime
# 0  0.975694  63.006642
# Runnning  bow factck.br
# /opt/conda/lib/python3.8/site-packages/sklearn/linear_model/_logistic.py:762: ConvergenceWarning: lbfgs failed to converge (status=1):
# STOP: TOTAL NO. of ITERATIONS REACHED LIMIT.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
# Please also refer to the documentation for alternative solver options:
#     https://scikit-learn.org/stable/modules/linear_model.html#logistic-regression
#   n_iter_i = _check_optimize_result(
#         pipeline scaling           model_name  \
# 0  bow_factck.br    none  Logistic Regression
#
#                                               params training_scoring  \
# 0  {'penalty': 'l2', 'max_iter': 80, 'fit_interce...               f1
#
#    training_score validation_scoring  validation_score  accuracy        f1  \
# 0        0.879698            roc_auc          0.603393  0.798479  0.784813
#
#     roc_auc  runtime
# 0  0.649293  0.12338
# Runnning  bow.swr liar
#        pipeline scaling   model_name                         params  \
# 0  bow.swr_liar    none  Naive Bayes  {'norm': False, 'alpha': 0.8}
#
#   training_scoring  training_score validation_scoring  validation_score  \
# 0               f1         0.54828            roc_auc          0.591772
#
#    accuracy        f1   roc_auc   runtime
# 0  0.606487  0.605598  0.599224  0.136738
# Runnning  bow.swr sbnc
# /opt/conda/lib/python3.8/site-packages/xgboost/sklearn.py:1224: UserWarning: The use of label encoder in XGBClassifier is deprecated and will be removed in a future release. To remove this warning, do the following: 1) Pass option use_label_encoder=False when constructing XGBClassifier object; and 2) Encode your labels (y) as integers starting with 0, i.e. 0, 1, 2, ..., [num_class - 1].
#   warnings.warn(label_encoder_deprecation_msg, UserWarning)
# [14:41:24] WARNING: ../src/learner.cc:1115: Starting in XGBoost 1.3.0, the default evaluation metric used with the objective 'binary:logistic' was changed from 'error' to 'logloss'. Explicitly set eval_metric if you'd like to restore the old behavior.
#        pipeline scaling model_name  \
# 0  bow.swr_sbnc    none    XGBoost
#
#                                               params training_scoring  \
# 0  {'learning_rate': 0.043846947416260156, 'max_d...               f1
#
#    training_score validation_scoring  validation_score  accuracy       f1  \
# 0        0.835986            roc_auc          0.784758   0.79703  0.79022
#
#     roc_auc    runtime
# 0  0.766342  31.075107
# Runnning  bow.swr fake.br
# [14:41:35] WARNING: ../src/learner.cc:1115: Starting in XGBoost 1.3.0, the default evaluation metric used with the objective 'binary:logistic' was changed from 'error' to 'logloss'. Explicitly set eval_metric if you'd like to restore the old behavior.
# /opt/conda/lib/python3.8/site-packages/xgboost/sklearn.py:1224: UserWarning: The use of label encoder in XGBClassifier is deprecated and will be removed in a future release. To remove this warning, do the following: 1) Pass option use_label_encoder=False when constructing XGBClassifier object; and 2) Encode your labels (y) as integers starting with 0, i.e. 0, 1, 2, ..., [num_class - 1].
#   warnings.warn(label_encoder_deprecation_msg, UserWarning)
#           pipeline scaling model_name  \
# 0  bow.swr_fake.br    none    XGBoost
#
#                                               params training_scoring  \
# 0  {'learning_rate': 0.1036111842654619, 'max_dep...               f1
#
#    training_score validation_scoring  validation_score  accuracy        f1  \
# 0        0.963559            roc_auc           0.96441  0.966667  0.966667
#
#     roc_auc    runtime
# 0  0.966667  46.308035
# Runnning  bow.swr factck.br
# /opt/conda/lib/python3.8/site-packages/sklearn/linear_model/_logistic.py:762: ConvergenceWarning: lbfgs failed to converge (status=1):
# STOP: TOTAL NO. of ITERATIONS REACHED LIMIT.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
# Please also refer to the documentation for alternative solver options:
#     https://scikit-learn.org/stable/modules/linear_model.html#logistic-regression
#   n_iter_i = _check_optimize_result(
#             pipeline scaling           model_name  \
# 0  bow.swr_factck.br    none  Logistic Regression
#
#                                               params training_scoring  \
# 0  {'penalty': 'none', 'max_iter': 10, 'fit_inter...               f1
#
#    training_score validation_scoring  validation_score  accuracy        f1  \
# 0        0.876953            roc_auc          0.687301  0.794677  0.779725
#
#     roc_auc  runtime
# 0  0.640521  0.09413
# Runnning  bow.stem liar
#         pipeline scaling   model_name                         params  \
# 0  bow.stem_liar    none  Naive Bayes  {'norm': False, 'alpha': 0.8}
#
#   training_scoring  training_score validation_scoring  validation_score  \
# 0               f1         0.54844            roc_auc          0.600101
#
#    accuracy        f1   roc_auc   runtime
# 0  0.615866  0.616177  0.611559  0.123718
# Runnning  bow.stem sbnc
# /opt/conda/lib/python3.8/site-packages/xgboost/sklearn.py:1224: UserWarning: The use of label encoder in XGBClassifier is deprecated and will be removed in a future release. To remove this warning, do the following: 1) Pass option use_label_encoder=False when constructing XGBClassifier object; and 2) Encode your labels (y) as integers starting with 0, i.e. 0, 1, 2, ..., [num_class - 1].
#   warnings.warn(label_encoder_deprecation_msg, UserWarning)
# [14:41:50] WARNING: ../src/learner.cc:1115: Starting in XGBoost 1.3.0, the default evaluation metric used with the objective 'binary:logistic' was changed from 'error' to 'logloss'. Explicitly set eval_metric if you'd like to restore the old behavior.
#         pipeline scaling model_name  \
# 0  bow.stem_sbnc    none    XGBoost
#
#                                               params training_scoring  \
# 0  {'learning_rate': 0.043846947416260156, 'max_d...               f1
#
#    training_score validation_scoring  validation_score  accuracy        f1  \
# 0        0.825404            roc_auc           0.79544  0.767327  0.758402
#
#     roc_auc    runtime
# 0  0.733145  30.527657
# Runnning  bow.stem fake.br
# /opt/conda/lib/python3.8/site-packages/sklearn/linear_model/_logistic.py:762: ConvergenceWarning: lbfgs failed to converge (status=1):
# STOP: TOTAL NO. of ITERATIONS REACHED LIMIT.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
# Please also refer to the documentation for alternative solver options:
#     https://scikit-learn.org/stable/modules/linear_model.html#logistic-regression
#   n_iter_i = _check_optimize_result(
#            pipeline scaling           model_name  \
# 0  bow.stem_fake.br    none  Logistic Regression
#
#                                               params training_scoring  \
# 0  {'penalty': 'l2', 'max_iter': 60, 'fit_interce...               f1
#
#    training_score validation_scoring  validation_score  accuracy       f1  \
# 0        0.965779            roc_auc           0.97309  0.967361  0.96736
#
#     roc_auc   runtime
# 0  0.967361  1.516396
# Runnning  bow.stem factck.br
# /opt/conda/lib/python3.8/site-packages/sklearn/linear_model/_logistic.py:762: ConvergenceWarning: lbfgs failed to converge (status=1):
# STOP: TOTAL NO. of ITERATIONS REACHED LIMIT.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
# Please also refer to the documentation for alternative solver options:
#     https://scikit-learn.org/stable/modules/linear_model.html#logistic-regression
#   n_iter_i = _check_optimize_result(
#              pipeline scaling           model_name  \
# 0  bow.stem_factck.br    none  Logistic Regression
#
#                                               params training_scoring  \
# 0  {'penalty': 'none', 'max_iter': 10, 'fit_inter...               f1
#
#    training_score validation_scoring  validation_score  accuracy        f1  \
# 0        0.877919            roc_auc          0.620758  0.768061  0.736121
#
#     roc_auc   runtime
# 0  0.566428  0.098414
# Runnning  bow.lemm liar
# /opt/conda/lib/python3.8/site-packages/sklearn/linear_model/_logistic.py:762: ConvergenceWarning: lbfgs failed to converge (status=1):
# STOP: TOTAL NO. of ITERATIONS REACHED LIMIT.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
# Please also refer to the documentation for alternative solver options:
#     https://scikit-learn.org/stable/modules/linear_model.html#logistic-regression
#   n_iter_i = _check_optimize_result(
#         pipeline scaling           model_name  \
# 0  bow.lemm_liar    none  Logistic Regression
#
#                                               params training_scoring  \
# 0  {'penalty': 'none', 'max_iter': 10, 'fit_inter...               f1
#
#    training_score validation_scoring  validation_score  accuracy        f1  \
# 0        0.530278            roc_auc           0.59344  0.605315  0.604157
#
#     roc_auc   runtime
# 0  0.597533  0.301757
# Runnning  bow.lemm sbnc
#         pipeline scaling     model_name  \
# 0  bow.lemm_sbnc    none  Random Forest
#
#                                               params training_scoring  \
# 0  {'n_estimators': 566, 'min_samples_split': 2, ...               f1
#
#    training_score validation_scoring  validation_score  accuracy        f1  \
# 0        0.816055            roc_auc          0.791374  0.762376  0.754404
#
#     roc_auc   runtime
# 0  0.730123  140.0891
# Runnning  bow.lemm fake.br
# [14:45:14] WARNING: ../src/learner.cc:1115: Starting in XGBoost 1.3.0, the default evaluation metric used with the objective 'binary:logistic' was changed from 'error' to 'logloss'. Explicitly set eval_metric if you'd like to restore the old behavior.
# /opt/conda/lib/python3.8/site-packages/xgboost/sklearn.py:1224: UserWarning: The use of label encoder in XGBClassifier is deprecated and will be removed in a future release. To remove this warning, do the following: 1) Pass option use_label_encoder=False when constructing XGBClassifier object; and 2) Encode your labels (y) as integers starting with 0, i.e. 0, 1, 2, ..., [num_class - 1].
#   warnings.warn(label_encoder_deprecation_msg, UserWarning)
#            pipeline scaling model_name  \
# 0  bow.lemm_fake.br    none    XGBoost
#
#                                               params training_scoring  \
# 0  {'learning_rate': 0.014239783131830445, 'max_d...               f1
#
#    training_score validation_scoring  validation_score  accuracy        f1  \
# 0        0.981164            roc_auc          0.983507  0.982639  0.982639
#
#     roc_auc    runtime
# 0  0.982639  56.411969
# Runnning  bow.lemm factck.br
# /opt/conda/lib/python3.8/site-packages/sklearn/linear_model/_logistic.py:762: ConvergenceWarning: lbfgs failed to converge (status=1):
# STOP: TOTAL NO. of ITERATIONS REACHED LIMIT.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
# Please also refer to the documentation for alternative solver options:
#     https://scikit-learn.org/stable/modules/linear_model.html#logistic-regression
#   n_iter_i = _check_optimize_result(
#              pipeline scaling           model_name  \
# 0  bow.lemm_factck.br    none  Logistic Regression
#
#                                               params training_scoring  \
# 0  {'penalty': 'l2', 'max_iter': 30, 'fit_interce...               f1
#
#    training_score validation_scoring  validation_score  accuracy        f1  \
# 0        0.886541            roc_auc          0.656018  0.813688  0.776602
#
#     roc_auc   runtime
# 0  0.608244  0.115272
# Runnning  bow.lemm.swr liar
#             pipeline scaling               model_name  \
# 0  bow.lemm.swr_liar    none  Support Vector Machines
#
#                                             params training_scoring  \
# 0  {'kernel': 'rbf', 'gamma': 'scale', 'C': 1.189}               f1
#
#    training_score validation_scoring  validation_score  accuracy        f1  \
# 0        0.505561            roc_auc          0.595265  0.611958  0.604726
#
#     roc_auc   runtime
# 0  0.596459  9.644128
# Runnning  bow.lemm.swr sbnc
# /opt/conda/lib/python3.8/site-packages/xgboost/sklearn.py:1224: UserWarning: The use of label encoder in XGBClassifier is deprecated and will be removed in a future release. To remove this warning, do the following: 1) Pass option use_label_encoder=False when constructing XGBClassifier object; and 2) Encode your labels (y) as integers starting with 0, i.e. 0, 1, 2, ..., [num_class - 1].
#   warnings.warn(label_encoder_deprecation_msg, UserWarning)
# [14:45:52] WARNING: ../src/learner.cc:1115: Starting in XGBoost 1.3.0, the default evaluation metric used with the objective 'binary:logistic' was changed from 'error' to 'logloss'. Explicitly set eval_metric if you'd like to restore the old behavior.
#             pipeline scaling model_name  \
# 0  bow.lemm.swr_sbnc    none    XGBoost
#
#                                               params training_scoring  \
# 0  {'learning_rate': 0.043846947416260156, 'max_d...               f1
#
#    training_score validation_scoring  validation_score  accuracy        f1  \
# 0        0.826994            roc_auc          0.777105  0.774752  0.764665
#
#     roc_auc    runtime
# 0  0.738217  29.853997
# Runnning  bow.lemm.swr fake.br
# [14:46:01] WARNING: ../src/learner.cc:1115: Starting in XGBoost 1.3.0, the default evaluation metric used with the objective 'binary:logistic' was changed from 'error' to 'logloss'. Explicitly set eval_metric if you'd like to restore the old behavior.
# /opt/conda/lib/python3.8/site-packages/xgboost/sklearn.py:1224: UserWarning: The use of label encoder in XGBClassifier is deprecated and will be removed in a future release. To remove this warning, do the following: 1) Pass option use_label_encoder=False when constructing XGBClassifier object; and 2) Encode your labels (y) as integers starting with 0, i.e. 0, 1, 2, ..., [num_class - 1].
#   warnings.warn(label_encoder_deprecation_msg, UserWarning)
#                pipeline scaling model_name  \
# 0  bow.lemm.swr_fake.br    none    XGBoost
#
#                                               params training_scoring  \
# 0  {'learning_rate': 0.01957975133212852, 'max_de...               f1
#
#    training_score validation_scoring  validation_score  accuracy       f1  \
# 0        0.981219            roc_auc          0.980035   0.98125  0.98125
#
#    roc_auc    runtime
# 0  0.98125  46.364801
# Runnning  bow.lemm.swr factck.br
# [14:46:11] WARNING: ../src/learner.cc:1115: Starting in XGBoost 1.3.0, the default evaluation metric used with the objective 'binary:logistic' was changed from 'error' to 'logloss'. Explicitly set eval_metric if you'd like to restore the old behavior.
# /opt/conda/lib/python3.8/site-packages/xgboost/sklearn.py:1224: UserWarning: The use of label encoder in XGBClassifier is deprecated and will be removed in a future release. To remove this warning, do the following: 1) Pass option use_label_encoder=False when constructing XGBClassifier object; and 2) Encode your labels (y) as integers starting with 0, i.e. 0, 1, 2, ..., [num_class - 1].
#   warnings.warn(label_encoder_deprecation_msg, UserWarning)
#                  pipeline scaling model_name  \
# 0  bow.lemm.swr_factck.br    none    XGBoost
#
#                                               params training_scoring  \
# 0  {'learning_rate': 0.044850167300919674, 'max_d...               f1
#
#    training_score validation_scoring  validation_score  accuracy        f1  \
# 0        0.883352            roc_auc          0.637328  0.809886  0.770384
#
#     roc_auc  runtime
# 0  0.599472   4.3695
# Runnning  tfidf liar
# /opt/conda/lib/python3.8/site-packages/sklearn/linear_model/_logistic.py:762: ConvergenceWarning: lbfgs failed to converge (status=1):
# STOP: TOTAL NO. of ITERATIONS REACHED LIMIT.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
# Please also refer to the documentation for alternative solver options:
#     https://scikit-learn.org/stable/modules/linear_model.html#logistic-regression
#   n_iter_i = _check_optimize_result(
#      pipeline scaling           model_name  \
# 0  tfidf_liar    none  Logistic Regression
#
#                                               params training_scoring  \
# 0  {'penalty': 'none', 'max_iter': 10, 'fit_inter...               f1
#
#    training_score validation_scoring  validation_score  accuracy        f1  \
# 0        0.598886            roc_auc          0.610295  0.605705  0.604521
#
#    roc_auc   runtime
# 0  0.61642  0.289573
# Runnning  tfidf sbnc
# /opt/conda/lib/python3.8/site-packages/xgboost/sklearn.py:1224: UserWarning: The use of label encoder in XGBClassifier is deprecated and will be removed in a future release. To remove this warning, do the following: 1) Pass option use_label_encoder=False when constructing XGBClassifier object; and 2) Encode your labels (y) as integers starting with 0, i.e. 0, 1, 2, ..., [num_class - 1].
#   warnings.warn(label_encoder_deprecation_msg, UserWarning)
# [14:46:17] WARNING: ../src/learner.cc:1115: Starting in XGBoost 1.3.0, the default evaluation metric used with the objective 'binary:logistic' was changed from 'error' to 'logloss'. Explicitly set eval_metric if you'd like to restore the old behavior.
#      pipeline scaling model_name  \
# 0  tfidf_sbnc    none    XGBoost
#
#                                               params training_scoring  \
# 0  {'learning_rate': 0.043846947416260156, 'max_d...               f1
#
#    training_score validation_scoring  validation_score  accuracy        f1  \
# 0        0.819077            roc_auc          0.807159  0.787129  0.782698
#
#     roc_auc    runtime
# 0  0.762449  54.344105
# Runnning  tfidf fake.br
#         pipeline scaling           model_name  \
# 0  tfidf_fake.br    none  Logistic Regression
#
#                                               params training_scoring  \
# 0  {'penalty': 'none', 'max_iter': 80, 'fit_inter...               f1
#
#    training_score validation_scoring  validation_score  accuracy        f1  \
# 0        0.959072            roc_auc          0.967014  0.963889  0.963889
#
#     roc_auc  runtime
# 0  0.963889  1.38094
# Runnning  tfidf factck.br
#           pipeline scaling               model_name  \
# 0  tfidf_factck.br    none  Support Vector Machines
#
#                                               params training_scoring  \
# 0  {'kernel': 'linear', 'gamma': 'auto', 'C': 1.733}               f1
#
#    training_score validation_scoring  validation_score  accuracy        f1  \
# 0        0.880547            roc_auc          0.657741  0.775665  0.760452
#
#     roc_auc   runtime
# 0  0.615696  0.185114
# Runnning  tfidf.swr liar
#          pipeline scaling   model_name                         params  \
# 0  tfidf.swr_liar    none  Naive Bayes  {'norm': False, 'alpha': 0.8}
#
#   training_scoring  training_score validation_scoring  validation_score  \
# 0               f1        0.515193            roc_auc          0.593617
#
#    accuracy        f1   roc_auc   runtime
# 0  0.607659  0.602999  0.594888  0.136423
# Runnning  tfidf.swr sbnc
# /opt/conda/lib/python3.8/site-packages/xgboost/sklearn.py:1224: UserWarning: The use of label encoder in XGBClassifier is deprecated and will be removed in a future release. To remove this warning, do the following: 1) Pass option use_label_encoder=False when constructing XGBClassifier object; and 2) Encode your labels (y) as integers starting with 0, i.e. 0, 1, 2, ..., [num_class - 1].
#   warnings.warn(label_encoder_deprecation_msg, UserWarning)
# [14:46:41] WARNING: ../src/learner.cc:1115: Starting in XGBoost 1.3.0, the default evaluation metric used with the objective 'binary:logistic' was changed from 'error' to 'logloss'. Explicitly set eval_metric if you'd like to restore the old behavior.
#          pipeline scaling model_name  \
# 0  tfidf.swr_sbnc    none    XGBoost
#
#                                               params training_scoring  \
# 0  {'learning_rate': 0.044850167300919674, 'max_d...               f1
#
#    training_score validation_scoring  validation_score  accuracy       f1  \
# 0        0.831304            roc_auc          0.783562  0.774752  0.76639
#
#     roc_auc   runtime
# 0  0.741445  24.98398
# Runnning  tfidf.swr fake.br
#             pipeline scaling               model_name  \
# 0  tfidf.swr_fake.br    none  Support Vector Machines
#
#                                               params training_scoring  \
# 0  {'kernel': 'linear', 'gamma': 'auto', 'C': 1.733}               f1
#
#    training_score validation_scoring  validation_score  accuracy        f1  \
# 0        0.962057            roc_auc          0.965278    0.9625  0.962499
#
#    roc_auc    runtime
# 0   0.9625  14.233476
# Runnning  tfidf.swr factck.br
#               pipeline scaling           model_name  \
# 0  tfidf.swr_factck.br    none  Logistic Regression
#
#                                               params training_scoring  \
# 0  {'penalty': 'none', 'max_iter': 80, 'fit_inter...               f1
#
#    training_score validation_scoring  validation_score  accuracy        f1  \
# 0        0.880549            roc_auc          0.665562  0.787072  0.781065
#
#     roc_auc   runtime
# 0  0.661046  0.112301
# Runnning  tfidf.stem liar
# /opt/conda/lib/python3.8/site-packages/sklearn/linear_model/_logistic.py:762: ConvergenceWarning: lbfgs failed to converge (status=1):
# STOP: TOTAL NO. of ITERATIONS REACHED LIMIT.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
# Please also refer to the documentation for alternative solver options:
#     https://scikit-learn.org/stable/modules/linear_model.html#logistic-regression
#   n_iter_i = _check_optimize_result(
#           pipeline scaling           model_name  \
# 0  tfidf.stem_liar    none  Logistic Regression
#
#                                               params training_scoring  \
# 0  {'penalty': 'none', 'max_iter': 10, 'fit_inter...               f1
#
#    training_score validation_scoring  validation_score  accuracy        f1  \
# 0        0.570034            roc_auc          0.599631  0.611567  0.612752
#
#    roc_auc  runtime
# 0  0.61501  0.28631
# Runnning  tfidf.stem sbnc
# [14:47:27] WARNING: ../src/learner.cc:1115: Starting in XGBoost 1.3.0, the default evaluation metric used with the objective 'binary:logistic' was changed from 'error' to 'logloss'. Explicitly set eval_metric if you'd like to restore the old behavior.
# /opt/conda/lib/python3.8/site-packages/xgboost/sklearn.py:1224: UserWarning: The use of label encoder in XGBClassifier is deprecated and will be removed in a future release. To remove this warning, do the following: 1) Pass option use_label_encoder=False when constructing XGBClassifier object; and 2) Encode your labels (y) as integers starting with 0, i.e. 0, 1, 2, ..., [num_class - 1].
#   warnings.warn(label_encoder_deprecation_msg, UserWarning)
#           pipeline scaling model_name  \
# 0  tfidf.stem_sbnc    none    XGBoost
#
#                                               params training_scoring  \
# 0  {'learning_rate': 0.044850167300919674, 'max_d...               f1
#
#    training_score validation_scoring  validation_score  accuracy        f1  \
# 0        0.817647            roc_auc          0.777423  0.762376  0.754949
#
#     roc_auc    runtime
# 0  0.731199  27.634219
# Runnning  tfidf.stem fake.br
#              pipeline scaling               model_name  \
# 0  tfidf.stem_fake.br    none  Support Vector Machines
#
#                                               params training_scoring  \
# 0  {'kernel': 'linear', 'gamma': 'auto', 'C': 1.733}               f1
#
#    training_score validation_scoring  validation_score  accuracy        f1  \
# 0        0.956902            roc_auc          0.967882    0.9625  0.962499
#
#    roc_auc    runtime
# 0   0.9625  11.721201
# Runnning  tfidf.stem factck.br
# /opt/conda/lib/python3.8/site-packages/sklearn/linear_model/_logistic.py:762: ConvergenceWarning: lbfgs failed to converge (status=1):
# STOP: TOTAL NO. of ITERATIONS REACHED LIMIT.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
# Please also refer to the documentation for alternative solver options:
#     https://scikit-learn.org/stable/modules/linear_model.html#logistic-regression
#   n_iter_i = _check_optimize_result(
#                pipeline scaling           model_name  \
# 0  tfidf.stem_factck.br    none  Logistic Regression
#
#                                               params training_scoring  \
# 0  {'penalty': 'none', 'max_iter': 10, 'fit_inter...               f1
#
#    training_score validation_scoring  validation_score  accuracy        f1  \
# 0        0.883343            roc_auc          0.687301  0.764259  0.744637
#
#    roc_auc   runtime
# 0  0.58938  0.094805
# Runnning  tfidf.lemm liar
# /opt/conda/lib/python3.8/site-packages/sklearn/linear_model/_logistic.py:762: ConvergenceWarning: lbfgs failed to converge (status=1):
# STOP: TOTAL NO. of ITERATIONS REACHED LIMIT.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
# Please also refer to the documentation for alternative solver options:
#     https://scikit-learn.org/stable/modules/linear_model.html#logistic-regression
#   n_iter_i = _check_optimize_result(
#           pipeline scaling           model_name  \
# 0  tfidf.lemm_liar    none  Logistic Regression
#
#                                               params training_scoring  \
# 0  {'penalty': 'none', 'max_iter': 10, 'fit_inter...               f1
#
#    training_score validation_scoring  validation_score  accuracy        f1  \
# 0         0.59677            roc_auc          0.615851  0.600625  0.600221
#
#     roc_auc   runtime
# 0  0.609673  0.310219
# Runnning  tfidf.lemm sbnc
# [14:48:06] WARNING: ../src/learner.cc:1115: Starting in XGBoost 1.3.0, the default evaluation metric used with the objective 'binary:logistic' was changed from 'error' to 'logloss'. Explicitly set eval_metric if you'd like to restore the old behavior.
# /opt/conda/lib/python3.8/site-packages/xgboost/sklearn.py:1224: UserWarning: The use of label encoder in XGBClassifier is deprecated and will be removed in a future release. To remove this warning, do the following: 1) Pass option use_label_encoder=False when constructing XGBClassifier object; and 2) Encode your labels (y) as integers starting with 0, i.e. 0, 1, 2, ..., [num_class - 1].
#   warnings.warn(label_encoder_deprecation_msg, UserWarning)
#           pipeline scaling model_name  \
# 0  tfidf.lemm_sbnc    none    XGBoost
#
#                                               params training_scoring  \
# 0  {'learning_rate': 0.044850167300919674, 'max_d...               f1
#
#    training_score validation_scoring  validation_score  accuracy        f1  \
# 0        0.822544            roc_auc          0.790179  0.789604  0.782789
#
#     roc_auc    runtime
# 0  0.759119  28.977821
# Runnning  tfidf.lemm fake.br
#              pipeline scaling           model_name  \
# 0  tfidf.lemm_fake.br    none  Logistic Regression
#
#                                               params training_scoring  \
# 0  {'penalty': 'none', 'max_iter': 80, 'fit_inter...               f1
#
#    training_score validation_scoring  validation_score  accuracy        f1  \
# 0        0.971087            roc_auc          0.982639  0.971528  0.971527
#
#     roc_auc   runtime
# 0  0.971528  1.349841
# Runnning  tfidf.lemm factck.br
#                pipeline scaling               model_name  \
# 0  tfidf.lemm_factck.br    none  Support Vector Machines
#
#                                               params training_scoring  \
# 0  {'kernel': 'sigmoid', 'gamma': 'scale', 'C': 2...               f1
#
#    training_score validation_scoring  validation_score  accuracy        f1  \
# 0        0.882171            roc_auc          0.612937  0.806084  0.788892
#
#     roc_auc   runtime
# 0  0.647803  0.167091
# Runnning  tfidf.lemm.swr liar
# /opt/conda/lib/python3.8/site-packages/sklearn/linear_model/_logistic.py:762: ConvergenceWarning: lbfgs failed to converge (status=1):
# STOP: TOTAL NO. of ITERATIONS REACHED LIMIT.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
# Please also refer to the documentation for alternative solver options:
#     https://scikit-learn.org/stable/modules/linear_model.html#logistic-regression
#   n_iter_i = _check_optimize_result(
#               pipeline scaling           model_name  \
# 0  tfidf.lemm.swr_liar    none  Logistic Regression
#
#                                               params training_scoring  \
# 0  {'penalty': 'none', 'max_iter': 10, 'fit_inter...               f1
#
#    training_score validation_scoring  validation_score  accuracy        f1  \
# 0        0.595495            roc_auc           0.60036  0.602579  0.602432
#
#    roc_auc  runtime
# 0  0.61106  0.27098
# Runnning  tfidf.lemm.swr sbnc
# /opt/conda/lib/python3.8/site-packages/xgboost/sklearn.py:1224: UserWarning: The use of label encoder in XGBClassifier is deprecated and will be removed in a future release. To remove this warning, do the following: 1) Pass option use_label_encoder=False when constructing XGBClassifier object; and 2) Encode your labels (y) as integers starting with 0, i.e. 0, 1, 2, ..., [num_class - 1].
#   warnings.warn(label_encoder_deprecation_msg, UserWarning)
# [14:48:23] WARNING: ../src/learner.cc:1115: Starting in XGBoost 1.3.0, the default evaluation metric used with the objective 'binary:logistic' was changed from 'error' to 'logloss'. Explicitly set eval_metric if you'd like to restore the old behavior.
#               pipeline scaling model_name  \
# 0  tfidf.lemm.swr_sbnc    none    XGBoost
#
#                                               params training_scoring  \
# 0  {'learning_rate': 0.044850167300919674, 'max_d...               f1
#
#    training_score validation_scoring  validation_score  accuracy        f1  \
# 0        0.828468            roc_auc          0.787149  0.764851  0.751666
#
#     roc_auc    runtime
# 0  0.723566  24.235038
# Runnning  tfidf.lemm.swr fake.br
# /opt/conda/lib/python3.8/site-packages/sklearn/linear_model/_logistic.py:762: ConvergenceWarning: lbfgs failed to converge (status=1):
# STOP: TOTAL NO. of ITERATIONS REACHED LIMIT.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
# Please also refer to the documentation for alternative solver options:
#     https://scikit-learn.org/stable/modules/linear_model.html#logistic-regression
#   n_iter_i = _check_optimize_result(
#                  pipeline scaling           model_name  \
# 0  tfidf.lemm.swr_fake.br    none  Logistic Regression
#
#                                               params training_scoring  \
# 0  {'penalty': 'none', 'max_iter': 20, 'fit_inter...               f1
#
#    training_score validation_scoring  validation_score  accuracy        f1  \
# 0        0.968867            roc_auc          0.980035  0.967361  0.967361
#
#     roc_auc   runtime
# 0  0.967361  1.141418
# Runnning  tfidf.lemm.swr factck.br
# [14:48:33] WARNING: ../src/learner.cc:1115: Starting in XGBoost 1.3.0, the default evaluation metric used with the objective 'binary:logistic' was changed from 'error' to 'logloss'. Explicitly set eval_metric if you'd like to restore the old behavior.
# /opt/conda/lib/python3.8/site-packages/xgboost/sklearn.py:1224: UserWarning: The use of label encoder in XGBClassifier is deprecated and will be removed in a future release. To remove this warning, do the following: 1) Pass option use_label_encoder=False when constructing XGBClassifier object; and 2) Encode your labels (y) as integers starting with 0, i.e. 0, 1, 2, ..., [num_class - 1].
#   warnings.warn(label_encoder_deprecation_msg, UserWarning)
#                    pipeline scaling model_name  \
# 0  tfidf.lemm.swr_factck.br    none    XGBoost
#
#                                               params training_scoring  \
# 0  {'learning_rate': 0.017958976695919917, 'max_d...               f1
#
#    training_score validation_scoring  validation_score  accuracy       f1  \
# 0        0.876921            roc_auc          0.612142  0.771863  0.71117
#
#     roc_auc  runtime
# 0  0.524442  6.71351

# %% [markdown]
# ## 5.  Results

# %%
results.best_model.sort_values(by=['dataset', 'accuracy'], ascending=False)
# Out:
#                                 pipeline               model_name  \
# 0                                bow.swr                  XGBoost
# 0                             tfidf.lemm                  XGBoost
# 0                                  tfidf                  XGBoost
# 0                              tfidf.swr                  XGBoost
# 0                           bow.lemm.swr                  XGBoost
# 0                                    bow                  XGBoost
# 0  paraphrase-multilingual-mpnet-base-v2  Support Vector Machines
# 0                               bow.stem                  XGBoost
# 0                         tfidf.lemm.swr                  XGBoost
# 0                             tfidf.stem                  XGBoost
# 0                               bow.lemm            Random Forest
# 0                   stsb-distilbert-base                  XGBoost
# 0  paraphrase-multilingual-mpnet-base-v2            Random Forest
# 0                   stsb-distilbert-base            Random Forest
# 0                               bow.stem              Naive Bayes
# 0                                    bow              Naive Bayes
# 0                           bow.lemm.swr  Support Vector Machines
# 0                             tfidf.stem      Logistic Regression
# 0                              tfidf.swr              Naive Bayes
# 0                                bow.swr              Naive Bayes
# 0                                  tfidf      Logistic Regression
# 0                               bow.lemm      Logistic Regression
# 0                         tfidf.lemm.swr      Logistic Regression
# 0                             tfidf.lemm      Logistic Regression
# 0                               bow.lemm                  XGBoost
# 0                           bow.lemm.swr                  XGBoost
# 0                                    bow                  XGBoost
# 0                             tfidf.lemm      Logistic Regression
# 0                               bow.stem      Logistic Regression
# 0                         tfidf.lemm.swr      Logistic Regression
# 0                                bow.swr                  XGBoost
# 0                                  tfidf      Logistic Regression
# 0                             tfidf.stem  Support Vector Machines
# 0                              tfidf.swr  Support Vector Machines
# 0  paraphrase-multilingual-mpnet-base-v2  Support Vector Machines
# 0                   stsb-distilbert-base      Logistic Regression
# 0                               bow.lemm      Logistic Regression
# 0                           bow.lemm.swr                  XGBoost
# 0                             tfidf.lemm  Support Vector Machines
# 0                                    bow      Logistic Regression
# 0                                bow.swr      Logistic Regression
# 0  paraphrase-multilingual-mpnet-base-v2      K-Nearest Neighbors
# 0                              tfidf.swr      Logistic Regression
# 0                                  tfidf  Support Vector Machines
# 0                         tfidf.lemm.swr                  XGBoost
# 0                   stsb-distilbert-base      Logistic Regression
# 0                               bow.stem      Logistic Regression
# 0                             tfidf.stem      Logistic Regression
#
#                                               params  training_score  \
# 0  {'learning_rate': 0.043846947416260156, 'max_d...        0.835986
# 0  {'learning_rate': 0.044850167300919674, 'max_d...        0.822544
# 0  {'learning_rate': 0.043846947416260156, 'max_d...        0.819077
# 0  {'learning_rate': 0.044850167300919674, 'max_d...        0.831304
# 0  {'learning_rate': 0.043846947416260156, 'max_d...        0.826994
# 0  {'learning_rate': 0.037999397928169254, 'max_d...        0.830805
# 0   {'kernel': 'poly', 'gamma': 'scale', 'C': 2.278}        0.792585
# 0  {'learning_rate': 0.043846947416260156, 'max_d...        0.825404
# 0  {'learning_rate': 0.044850167300919674, 'max_d...        0.828468
# 0  {'learning_rate': 0.044850167300919674, 'max_d...        0.817647
# 0  {'n_estimators': 566, 'min_samples_split': 2, ...        0.816055
# 0  {'learning_rate': 0.15461527961560703, 'max_de...        0.760306
# 0  {'n_estimators': 722, 'min_samples_split': 2, ...        0.511372
# 0  {'n_estimators': 566, 'min_samples_split': 2, ...        0.493594
# 0                      {'norm': False, 'alpha': 0.8}        0.548440
# 0                      {'norm': False, 'alpha': 0.8}        0.551215
# 0    {'kernel': 'rbf', 'gamma': 'scale', 'C': 1.189}        0.505561
# 0  {'penalty': 'none', 'max_iter': 10, 'fit_inter...        0.570034
# 0                      {'norm': False, 'alpha': 0.8}        0.515193
# 0                      {'norm': False, 'alpha': 0.8}        0.548280
# 0  {'penalty': 'none', 'max_iter': 10, 'fit_inter...        0.598886
# 0  {'penalty': 'none', 'max_iter': 10, 'fit_inter...        0.530278
# 0  {'penalty': 'none', 'max_iter': 10, 'fit_inter...        0.595495
# 0  {'penalty': 'none', 'max_iter': 10, 'fit_inter...        0.596770
# 0  {'learning_rate': 0.014239783131830445, 'max_d...        0.981164
# 0  {'learning_rate': 0.01957975133212852, 'max_de...        0.981219
# 0  {'learning_rate': 0.13740346640696569, 'max_de...        0.965594
# 0  {'penalty': 'none', 'max_iter': 80, 'fit_inter...        0.971087
# 0  {'penalty': 'l2', 'max_iter': 60, 'fit_interce...        0.965779
# 0  {'penalty': 'none', 'max_iter': 20, 'fit_inter...        0.968867
# 0  {'learning_rate': 0.1036111842654619, 'max_dep...        0.963559
# 0  {'penalty': 'none', 'max_iter': 80, 'fit_inter...        0.959072
# 0  {'kernel': 'linear', 'gamma': 'auto', 'C': 1.733}        0.956902
# 0  {'kernel': 'linear', 'gamma': 'auto', 'C': 1.733}        0.962057
# 0  {'kernel': 'linear', 'gamma': 'auto', 'C': 4.456}        0.838821
# 0  {'penalty': 'l2', 'max_iter': 80, 'fit_interce...        0.821892
# 0  {'penalty': 'l2', 'max_iter': 30, 'fit_interce...        0.886541
# 0  {'learning_rate': 0.044850167300919674, 'max_d...        0.883352
# 0  {'kernel': 'sigmoid', 'gamma': 'scale', 'C': 2...        0.882171
# 0  {'penalty': 'l2', 'max_iter': 80, 'fit_interce...        0.879698
# 0  {'penalty': 'none', 'max_iter': 10, 'fit_inter...        0.876953
# 0  {'weights': 'uniform', 'n_neighbors': 7, 'algo...        0.889738
# 0  {'penalty': 'none', 'max_iter': 80, 'fit_inter...        0.880549
# 0  {'kernel': 'linear', 'gamma': 'auto', 'C': 1.733}        0.880547
# 0  {'learning_rate': 0.017958976695919917, 'max_d...        0.876921
# 0  {'penalty': 'l2', 'max_iter': 30, 'fit_interce...        0.853673
# 0  {'penalty': 'none', 'max_iter': 10, 'fit_inter...        0.877919
# 0  {'penalty': 'none', 'max_iter': 10, 'fit_inter...        0.883343
#
#   validation_scoring  validation_score  accuracy        f1   roc_auc  \
# 0            roc_auc          0.784758  0.797030  0.790220  0.766342
# 0            roc_auc          0.790179  0.789604  0.782789  0.759119
# 0            roc_auc          0.807159  0.787129  0.782698  0.762449
# 0            roc_auc          0.783562  0.774752  0.766390  0.741445
# 0            roc_auc          0.777105  0.774752  0.764665  0.738217
# 0            roc_auc          0.796636  0.769802  0.763858  0.741650
# 0            roc_auc          0.756537  0.769802  0.762865  0.739498
# 0            roc_auc          0.795440  0.767327  0.758402  0.733145
# 0            roc_auc          0.787149  0.764851  0.751666  0.723566
# 0            roc_auc          0.777423  0.762376  0.754949  0.731199
# 0            roc_auc          0.791374  0.762376  0.754404  0.730123
# 0            roc_auc          0.677695  0.683168  0.674654  0.650564
# 0            roc_auc          0.620680  0.630715  0.622811  0.614465
# 0            roc_auc          0.606106  0.622509  0.611856  0.603911
# 0            roc_auc          0.600101  0.615866  0.616177  0.611559
# 0            roc_auc          0.595368  0.613912  0.613370  0.607433
# 0            roc_auc          0.595265  0.611958  0.604726  0.596459
# 0            roc_auc          0.599631  0.611567  0.612752  0.615010
# 0            roc_auc          0.593617  0.607659  0.602999  0.594888
# 0            roc_auc          0.591772  0.606487  0.605598  0.599224
# 0            roc_auc          0.610295  0.605705  0.604521  0.616420
# 0            roc_auc          0.593440  0.605315  0.604157  0.597533
# 0            roc_auc          0.600360  0.602579  0.602432  0.611060
# 0            roc_auc          0.615851  0.600625  0.600221  0.609673
# 0            roc_auc          0.983507  0.982639  0.982639  0.982639
# 0            roc_auc          0.980035  0.981250  0.981250  0.981250
# 0            roc_auc          0.967882  0.975694  0.975693  0.975694
# 0            roc_auc          0.982639  0.971528  0.971527  0.971528
# 0            roc_auc          0.973090  0.967361  0.967360  0.967361
# 0            roc_auc          0.980035  0.967361  0.967361  0.967361
# 0            roc_auc          0.964410  0.966667  0.966667  0.966667
# 0            roc_auc          0.967014  0.963889  0.963889  0.963889
# 0            roc_auc          0.967882  0.962500  0.962499  0.962500
# 0            roc_auc          0.965278  0.962500  0.962499  0.962500
# 0            roc_auc          0.858507  0.845139  0.845122  0.845139
# 0            roc_auc          0.835938  0.838889  0.838869  0.838889
# 0            roc_auc          0.656018  0.813688  0.776602  0.608244
# 0            roc_auc          0.637328  0.809886  0.770384  0.599472
# 0            roc_auc          0.612937  0.806084  0.788892  0.647803
# 0            roc_auc          0.603393  0.798479  0.784813  0.649293
# 0            roc_auc          0.687301  0.794677  0.779725  0.640521
# 0            roc_auc          0.677757  0.790875  0.762076  0.600026
# 0            roc_auc          0.665562  0.787072  0.781065  0.661046
# 0            roc_auc          0.657741  0.775665  0.760452  0.615696
# 0            roc_auc          0.612142  0.771863  0.711170  0.524442
# 0            roc_auc          0.649920  0.768061  0.760600  0.629876
# 0            roc_auc          0.620758  0.768061  0.736121  0.566428
# 0            roc_auc          0.687301  0.764259  0.744637  0.589380
#
#        runtime    dataset
# 0    31.075107       sbnc
# 0    28.977821       sbnc
# 0    54.344105       sbnc
# 0    24.983980       sbnc
# 0    29.853997       sbnc
# 0    53.888175       sbnc
# 0     1.884847       sbnc
# 0    30.527657       sbnc
# 0    24.235038       sbnc
# 0    27.634219       sbnc
# 0   140.089100       sbnc
# 0    57.331960       sbnc
# 0  2529.194057       liar
# 0  1445.481359       liar
# 0     0.123718       liar
# 0     0.297642       liar
# 0     9.644128       liar
# 0     0.286310       liar
# 0     0.136423       liar
# 0     0.136738       liar
# 0     0.289573       liar
# 0     0.301757       liar
# 0     0.270980       liar
# 0     0.310219       liar
# 0    56.411969    fake.br
# 0    46.364801    fake.br
# 0    63.006642    fake.br
# 0     1.349841    fake.br
# 0     1.516396    fake.br
# 0     1.141418    fake.br
# 0    46.308035    fake.br
# 0     1.380940    fake.br
# 0    11.721201    fake.br
# 0    14.233476    fake.br
# 0    16.568888    fake.br
# 0     1.329329    fake.br
# 0     0.115272  factck.br
# 0     4.369500  factck.br
# 0     0.167091  factck.br
# 0     0.123380  factck.br
# 0     0.094130  factck.br
# 0     0.138280  factck.br
# 0     0.112301  factck.br
# 0     0.185114  factck.br
# 0     6.713510  factck.br
# 0     0.219472  factck.br
# 0     0.098414  factck.br
# 0     0.094805  factck.br

# %% [markdown]
# The best model, measured by accuracy, for each dataset is listed below

# %%
best.sort_values(by=['accuracy'], ascending=False).groupby(by='dataset').first()
# Out:
#                                         pipeline           model_name  \
# dataset
# factck.br                               bow.lemm  Logistic Regression
# fake.br                                 bow.lemm              XGBoost
# liar       paraphrase-multilingual-mpnet-base-v2        Random Forest
# sbnc                                     bow.swr              XGBoost
#
#                                                       params  training_score  \
# dataset
# factck.br  {'penalty': 'l2', 'max_iter': 30, 'fit_interce...        0.886541
# fake.br    {'learning_rate': 0.014239783131830445, 'max_d...        0.981164
# liar       {'n_estimators': 722, 'min_samples_split': 2, ...        0.511372
# sbnc       {'learning_rate': 0.043846947416260156, 'max_d...        0.835986
#
#           validation_scoring  validation_score  accuracy        f1   roc_auc  \
# dataset
# factck.br            roc_auc          0.656018  0.813688  0.776602  0.608244
# fake.br              roc_auc          0.983507  0.982639  0.982639  0.982639
# liar                 roc_auc          0.620680  0.630715  0.622811  0.614465
# sbnc                 roc_auc          0.784758  0.797030  0.790220  0.766342
#
#                runtime
# dataset
# factck.br     0.115272
# fake.br      56.411969
# liar       2529.194057
# sbnc         31.075107

# %% [markdown]
# The best model for each dataset, as measured by the ROC AUC metric, is listed below

# %%
best.sort_values(by=['roc_auc'], ascending=False).groupby(by='dataset').first()
# Out:
#             pipeline           model_name  \
# dataset
# factck.br  tfidf.swr  Logistic Regression
# fake.br     bow.lemm              XGBoost
# liar           tfidf  Logistic Regression
# sbnc         bow.swr              XGBoost
#
#                                                       params  training_score  \
# dataset
# factck.br  {'penalty': 'none', 'max_iter': 80, 'fit_inter...        0.880549
# fake.br    {'learning_rate': 0.014239783131830445, 'max_d...        0.981164
# liar       {'penalty': 'none', 'max_iter': 10, 'fit_inter...        0.598886
# sbnc       {'learning_rate': 0.043846947416260156, 'max_d...        0.835986
#
#           validation_scoring  validation_score  accuracy        f1   roc_auc  \
# dataset
# factck.br            roc_auc          0.665562  0.787072  0.781065  0.661046
# fake.br              roc_auc          0.983507  0.982639  0.982639  0.982639
# liar                 roc_auc          0.610295  0.605705  0.604521  0.616420
# sbnc                 roc_auc          0.784758  0.797030  0.790220  0.766342
#
#              runtime
# dataset
# factck.br   0.112301
# fake.br    56.411969
# liar        0.289573
# sbnc       31.075107

# %% [markdown]
# ## References
# <a name="bot"></a>
# [1]: Souza, S.M.P. et al. *Tuning machine learning models to detect bots on Twitter*. 2020 Workshop on Communication Networks and Power Systems (WCNPS). Brasilia, 2020.
#
# <a name="liar"></a>
# [2] Wlliam Yang Wang, "Liar, Liar Pants on Fire": A New Benchmark Dataset for Fake News Detection, to appear in Proceedings of the 55th Annual Meeting of the Association for Computational Linguistics (ACL 2017), short paper, Vancouver, BC, Canada, July 30-August 4, ACL.
#
# <a name="snbc"></a>
# [3]. A.  Bharadwaj,  B.  Ashar,  P.  Barbhaya,  R.  Bhatia,  Z.  Shaikh,  Source based fake news classification using machine learning (Aug 2020).URL https://kaggle.com/ruchi798/source-based-news-classification
#
# <a name="factbr"></a>
# [4]. J. a. Moreno, G. Bressan, Factck.br:  A new dataset to study fake news,in:  Proceedings of the 25th Brazillian Symposium on Multimedia andthe  Web,  WebMedia  ’19,  Association  for  Computing  Machinery,  NewYork, NY, USA, 2019, p. 525–527.  doi:10.1145/3323503.3361698.
#
# <a name="fakebr"></a>
# [5]. Monteiro R.A., Santos R.L.S., Pardo T.A.S., de Almeida T.A., Ruiz E.E.S., Vale O.A. (2018) Contributions to the Study of Fake News in Portuguese: New Corpus and Automatic Detection Results. In: Villavicencio A. et al. (eds) Computational Processing of the Portuguese Language. PROPOR 2018. Lecture Notes in Computer Science, vol 11122. Springer, Cham.
